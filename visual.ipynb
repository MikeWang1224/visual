# %%
import os
HOME = os.getcwd()
print(HOME)
# Out:
# /content

# %%
# !git clone https://github.com/SkalskiP/yolov9.git
# %cd yolov9
# !pip install -r requirements.txt -q
# Out:
# Cloning into 'yolov9'...
# remote: Enumerating objects: 325, done.
# remote: Total 325 (delta 0), reused 0 (delta 0), pack-reused 325 (from 1)
# Receiving objects: 100% (325/325), 2.25 MiB | 8.75 MiB/s, done.
# Resolving deltas: 100% (162/162), done.
# /content/yolov9
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 66.1 MB/s eta 0:00:00

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !wget -P {HOME}/weights -q https://github.com/WongKinYiu/yolov9/releases/download/v0.1/yolov9-c.pt
# !wget -P {HOME}/weights -q https://github.com/WongKinYiu/yolov9/releases/download/v0.1/yolov9-e.pt
# !wget -P {HOME}/weights -q https://github.com/WongKinYiu/yolov9/releases/download/v0.1/gelan-c.pt
# !wget -P {HOME}/weights -q https://github.com/WongKinYiu/yolov9/releases/download/v0.1/gelan-e.pt

# %%
# !ls -la {HOME}/weights
# Out:
# total 402448
# drwxr-xr-x 2 root root      4096 Dec 23 06:54 .
# drwxr-xr-x 1 root root      4096 Dec 23 06:54 ..
# -rw-r--r-- 1 root root  51508261 Feb 18  2024 gelan-c.pt
# -rw-r--r-- 1 root root 117203713 Feb 18  2024 gelan-e.pt
# -rw-r--r-- 1 root root 103153312 Feb 18  2024 yolov9-c.pt
# -rw-r--r-- 1 root root 140217688 Feb 18  2024 yolov9-e.pt

# %%
from os import listdir
from os.path import isfile, join
from IPython.display import Image
from matplotlib import pyplot as plt
os.system(f'rm -r {HOME}/yolov9/runs/detect')

onlyfiles = [f for f in listdir(f'/content/drive/MyDrive/data2')if isfile(join(f'/content/drive/MyDrive/data2', f))]

i=1
for filename in onlyfiles:
  os.system(f'python detect.py --weights {HOME}/weights/gelan-c.pt --conf 0.1 --source /content/drive/MyDrive/data2/{filename} --device 0 --classes 15 16')
  #display(Image(f'{HOME}/yolov9/runs/detect/exp/{filename}'))
  output_image_path = f"{HOME}/yolov9/runs/detect/exp{''if i ==1 else i}/{filename}"

    # 显示图片
  print(f'第 {i} 張圖片')
  plt.imshow(plt.imread(output_image_path))
  plt.show()
  #display(Image(filename=output_image_path, width=600))
  #Image(filename=f"{HOME}/yolov9/runs/detect/exp{''if i ==1 else i}/{filename}", width=600)
  #input()
  i+=1
# Out:
# Output hidden; open in https://colab.research.google.com to view.
